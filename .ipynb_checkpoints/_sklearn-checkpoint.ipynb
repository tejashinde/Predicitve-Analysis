# %%
import numpy
import scipy
from matplotlib import pyplot as pyplot
import sklearn
import seaborn
import csv
import pandas

# %% [markdown]
# ## a) Sckit learn provided an object oriented interface centered around the concept of an Estimator.

# %%
with open('data/colon_delimited_stock_prices.txt') as file:
    reader = csv.reader(file , delimiter = ':')
    for row in reader:
        if len(row) > 1:
            print(row)
#         print("Date : " + row[0].split()[0])
#         print(row[0].split(':'))
# Out:
# ['date', 'symbol', 'closing_price']
# ['6/20/2014', 'AAPL', '90.9']
# ['16/20/2014', 'MSFT', '41.68']
# ['6/20/2014', 'FB', '64.5']

# %%
file = pandas.read_csv('data/flights.csv')

# %%
nandf = file[file.isnull().any(axis=1)].head(20)

# %%
dropCols = lambda x : x.drop(x[x.isnull().any(axis = 1) == False])

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-116-c72dbf5813ae> in <module>
# ----> 1 dropCols(nandf)
#
# <ipython-input-115-ac1bd94a867f> in <lambda>(x)
# ----> 1 dropCols = lambda x : pandas.drop(x[x.isnull().any(axis = 1) == False])
#
# AttributeError: module 'pandas' has no attribute 'drop'

# %%
nandf[nandf.isnull().any(axis = 1)]
# Out:
#       year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 330   2013      1    1    1807.0       29.0    2251.0        NaN      UA
# 403   2013      1    1       NaN        NaN       NaN        NaN      AA
# 404   2013      1    1       NaN        NaN       NaN        NaN      AA
# 855   2013      1    2    2145.0       16.0       NaN        NaN      UA
# 858   2013      1    2       NaN        NaN       NaN        NaN      AA
# 859   2013      1    2       NaN        NaN       NaN        NaN      AA
# 860   2013      1    2       NaN        NaN       NaN        NaN      UA
# 1067  2013      1    3    1348.0       -2.0    1821.0        NaN      DL
# 1275  2013      1    3       NaN        NaN       NaN        NaN      AA
# 1276  2013      1    3       NaN        NaN       NaN        NaN      AA
# 1277  2013      1    3       NaN        NaN       NaN        NaN      AA
# 1278  2013      1    3       NaN        NaN       NaN        NaN      AA
# ...

# %%
nandf
# Out:
#       year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 330   2013      1    1    1807.0       29.0    2251.0        NaN      UA
# 403   2013      1    1       NaN        NaN       NaN        NaN      AA
# 404   2013      1    1       NaN        NaN       NaN        NaN      AA
# 855   2013      1    2    2145.0       16.0       NaN        NaN      UA
# 858   2013      1    2       NaN        NaN       NaN        NaN      AA
# 859   2013      1    2       NaN        NaN       NaN        NaN      AA
# 860   2013      1    2       NaN        NaN       NaN        NaN      UA
# 1067  2013      1    3    1348.0       -2.0    1821.0        NaN      DL
# 1275  2013      1    3       NaN        NaN       NaN        NaN      AA
# 1276  2013      1    3       NaN        NaN       NaN        NaN      AA
# 1277  2013      1    3       NaN        NaN       NaN        NaN      AA
# 1278  2013      1    3       NaN        NaN       NaN        NaN      AA
# ...

# %%
nandf[nandf.columns.isnull().any]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-114-c5816b40f8be> in <module>
# ----> 1 nandf[nandf.columns.isnull().any]
#
# d:\programs\python\python37-32\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2663
#    2664     def __getitem__(self, key):
# -> 2665         key = com._apply_if_callable(key, self)
#    2666
#    2667         # shortcut if we are an actual column
#
# d:\programs\python\python37-32\lib\site-packages\pandas\core\common.py in _apply_if_callable(maybe_callable, obj, **kwargs)
#     406
#     407     if callable(maybe_callable):
# --> 408         return maybe_callable(obj, **kwargs)
#     409
#     410     return maybe_callable
#
# d:\programs\python\python37-32\lib\site-packages\numpy\core\_methods.py in _any(a, axis, dtype, out, keepdims)
#      41
# ...
